# %%
from TextRank_sentence_summa import TextRank
# Out:
# /Applications/anaconda3/envs/ForML/lib/python3.9/site-packages/ckiptagger/model_ws.py:106: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# 2022-12-08 22:10:48.106639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-08 22:10:48.139061: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# /Applications/anaconda3/envs/ForML/lib/python3.9/site-packages/ckiptagger/model_pos.py:56: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)
# /Applications/anaconda3/envs/ForML/lib/python3.9/site-packages/ckiptagger/model_ner.py:57: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(hidden_d, name=name)

# %% [markdown]
# ## 有兩種使用方法

# %% [markdown]
# ### 第一種

# %%
# 創建 TextRank object
tr = TextRank()

# 輸入要分析的文本
tr.import_document(folder_name = 'text', file_name = 'bnext_news_72945')

# 分析
# method: 有 'overlap', 'tfidf', 'bm25' 三種，不指定的話預設使用 'overlap'，也就是 TextRank 的原始方法。
tr.analyze(method = 'overlap')  

# 輸出結果
tr.print_top_n_result(num = 10)
# Out:
# 0.047042273000621596 FCC主席Jessica Rosenworcel指出，這些廠商的電信與監控產品會對國家與國民安全構成不可接受（unacceptable）的風險，不過FCC實際上並未全面禁止所有產品，如果海能達、海康威視與大華科技三間公司能夠證明，他們旗下用於公共安全、政府設施安全、重要實體監管以及其他國家安全的設備，是銷售給一般消費者，或具有嚴格的安全機制，有可能仍會獲得FCC的許可
#
# 0.045434314287353096 11/25，美國聯邦傳播委員會（Federal Communications Commission，FCC）以國家安全風險為由，宣布禁止華為（Huawei）、中興（ZTE）與海能達（Hytera）、海康威視（Hikvision）與大華科技（Dahua）等中國大廠在美販售或進口的通訊與監控設備
#
# 0.042824866284834 同年11月，美國總統拜登簽署《安全設備法》（Secure Equipment Act），要求FCC不可審核或是同意授權任何構成國安風險的設備申請，尤其針對名單上的華為、中興等中國廠商，此法不僅可以解決先前非聯邦資金採購設備的問題，亦被外界視為重挫中國電信與科技大廠的重大立法案
#
# 0.03968425884102916 同時，FCC專員Carr也呼籲政府處理「華為漏洞」，並指出先前已被替換的網路設備都是由聯邦出資購買，因此仍有企業鑽漏洞，私下購買一樣不安全的產品來使用，而這樣的行為還是會導致風險發生
#
# 0.038034638305993275 綜合上述例子，可見由美、英、加、澳、紐五國組成的「五眼聯盟（Five Eyes Alliance，FVEY）」皆出於安全與風險考量，紛紛提出措施防備中國公司的電信公司、設備，而相繼出手的大國可能都會對華為、中興等廠商造成不少影響
#
# 0.037703583796656746 雖然過去FCC推出黑名單、點明哪些廠商的產品有風險，還禁止企業使用聯邦資金購買這些設備，但是在過去幾年中，FCC依然繼續許可這些設備在市面上販售，只要這類商品獲得授權章，廠商就能持續進貨到美國，賣給其他自掏腰包的買家
#
# 0.03700768816139613 FCC的新管制政策啟動後，華為、中興、海能達、海康威視與大華科技將無法在美進口與販售其電信設備、影像監視器，預期將讓銷售情況雪上加霜，並且連帶波及到這些廠商背後供應商， 如台灣的晶相光、矽力–KY等
#
# 0.03628856244152909 作為進一步打擊中國電信與科技公司的行動，FFC近日表示不再授權黑名單（covered list）內的公司在美販售或進口其設備，華為、中興、海能達、海康威視（Hikvision）與大華科技（Dahua）均列名其中
#
# 0.03615397287203028 英國近日也考量安全風險，仿效美國採取類似措施，禁止各部門在「敏感（Sensitive）」的政府網站上安裝中國公司出產的監控設備
#
# 0.03573004947011017 根據Reuters報導，海康威視聲稱自己的產品不會危及美國國安，並指出對想要保護自己、家庭或財產的美國小公司、地方政府、學校單位與消費者來說，FCC的決定只會造成負擔，而不會真正保護到國家安全

# %% [markdown]
# ### 第二種

# %%
# 創建 TextRank object
tr = TextRank()

# 一行解決方案，一次完成第一種方法的所有功能。
tr.lazy_start(folder_name = 'text', file_name = 'bnext_news_72945', num = 10, method = 'tfidf')
# Out:
# 0.044354676849679586 FCC主席Jessica Rosenworcel指出，這些廠商的電信與監控產品會對國家與國民安全構成不可接受（unacceptable）的風險，不過FCC實際上並未全面禁止所有產品，如果海能達、海康威視與大華科技三間公司能夠證明，他們旗下用於公共安全、政府設施安全、重要實體監管以及其他國家安全的設備，是銷售給一般消費者，或具有嚴格的安全機制，有可能仍會獲得FCC的許可
#
# 0.04102851982995048 11/25，美國聯邦傳播委員會（Federal Communications Commission，FCC）以國家安全風險為由，宣布禁止華為（Huawei）、中興（ZTE）與海能達（Hytera）、海康威視（Hikvision）與大華科技（Dahua）等中國大廠在美販售或進口的通訊與監控設備
#
# 0.03878360420911449 同年11月，美國總統拜登簽署《安全設備法》（Secure Equipment Act），要求FCC不可審核或是同意授權任何構成國安風險的設備申請，尤其針對名單上的華為、中興等中國廠商，此法不僅可以解決先前非聯邦資金採購設備的問題，亦被外界視為重挫中國電信與科技大廠的重大立法案
#
# 0.03870662727173249 作為進一步打擊中國電信與科技公司的行動，FFC近日表示不再授權黑名單（covered list）內的公司在美販售或進口其設備，華為、中興、海能達、海康威視（Hikvision）與大華科技（Dahua）均列名其中
#
# 0.037733163777649986 FCC的新管制政策啟動後，華為、中興、海能達、海康威視與大華科技將無法在美進口與販售其電信設備、影像監視器，預期將讓銷售情況雪上加霜，並且連帶波及到這些廠商背後供應商， 如台灣的晶相光、矽力–KY等
#
# 0.03642349893612741 雖然過去FCC推出黑名單、點明哪些廠商的產品有風險，還禁止企業使用聯邦資金購買這些設備，但是在過去幾年中，FCC依然繼續許可這些設備在市面上販售，只要這類商品獲得授權章，廠商就能持續進貨到美國，賣給其他自掏腰包的買家
#
# 0.035626198325439944 加拿大也在今年5月宣布，禁止境內電信業者在5G網路中安裝華為與中興的產品，所有已安裝設備的企業必須停止使用，並立即移除
#
# 0.034437058767349836 澳洲則是早在2018年就基於安全考量，禁止華為在澳洲參與5G網路開發，指出這間公司的加入「可能會受到外國政府的指示」，風險實在太大
#
# 0.03356797408024409 2021年3月，華為、中興、海能達、海康威視與大華科技五間中國公司就被FCC認定有國安威脅，而列入黑名單
#
# 0.03320829273621232 2020年，美國前總統川普曾簽署《安全可信通訊網路法》（Secure and Trusted Communications Networks Act），要求美國電信公司拆除並更換「可疑的外國網路設備」，換言之就是華為與中興提供的產品

# %%
# 輸出更多的句子數
tr.print_top_n_result(15)
# Out:
# 0.044354676849679586 FCC主席Jessica Rosenworcel指出，這些廠商的電信與監控產品會對國家與國民安全構成不可接受（unacceptable）的風險，不過FCC實際上並未全面禁止所有產品，如果海能達、海康威視與大華科技三間公司能夠證明，他們旗下用於公共安全、政府設施安全、重要實體監管以及其他國家安全的設備，是銷售給一般消費者，或具有嚴格的安全機制，有可能仍會獲得FCC的許可
#
# 0.04102851982995048 11/25，美國聯邦傳播委員會（Federal Communications Commission，FCC）以國家安全風險為由，宣布禁止華為（Huawei）、中興（ZTE）與海能達（Hytera）、海康威視（Hikvision）與大華科技（Dahua）等中國大廠在美販售或進口的通訊與監控設備
#
# 0.03878360420911449 同年11月，美國總統拜登簽署《安全設備法》（Secure Equipment Act），要求FCC不可審核或是同意授權任何構成國安風險的設備申請，尤其針對名單上的華為、中興等中國廠商，此法不僅可以解決先前非聯邦資金採購設備的問題，亦被外界視為重挫中國電信與科技大廠的重大立法案
#
# 0.03870662727173249 作為進一步打擊中國電信與科技公司的行動，FFC近日表示不再授權黑名單（covered list）內的公司在美販售或進口其設備，華為、中興、海能達、海康威視（Hikvision）與大華科技（Dahua）均列名其中
#
# 0.037733163777649986 FCC的新管制政策啟動後，華為、中興、海能達、海康威視與大華科技將無法在美進口與販售其電信設備、影像監視器，預期將讓銷售情況雪上加霜，並且連帶波及到這些廠商背後供應商， 如台灣的晶相光、矽力–KY等
#
# 0.03642349893612741 雖然過去FCC推出黑名單、點明哪些廠商的產品有風險，還禁止企業使用聯邦資金購買這些設備，但是在過去幾年中，FCC依然繼續許可這些設備在市面上販售，只要這類商品獲得授權章，廠商就能持續進貨到美國，賣給其他自掏腰包的買家
#
# 0.035626198325439944 加拿大也在今年5月宣布，禁止境內電信業者在5G網路中安裝華為與中興的產品，所有已安裝設備的企業必須停止使用，並立即移除
#
# 0.034437058767349836 澳洲則是早在2018年就基於安全考量，禁止華為在澳洲參與5G網路開發，指出這間公司的加入「可能會受到外國政府的指示」，風險實在太大
#
# 0.03356797408024409 2021年3月，華為、中興、海能達、海康威視與大華科技五間中國公司就被FCC認定有國安威脅，而列入黑名單
#
# 0.03320829273621232 2020年，美國前總統川普曾簽署《安全可信通訊網路法》（Secure and Trusted Communications Networks Act），要求美國電信公司拆除並更換「可疑的外國網路設備」，換言之就是華為與中興提供的產品
#
# 0.033141992276384265 同時，FCC專員Carr也呼籲政府處理「華為漏洞」，並指出先前已被替換的網路設備都是由聯邦出資購買，因此仍有企業鑽漏洞，私下購買一樣不安全的產品來使用，而這樣的行為還是會導致風險發生
#
# 0.032764293873418684 綜合上述例子，可見由美、英、加、澳、紐五國組成的「五眼聯盟（Five Eyes Alliance，FVEY）」皆出於安全與風險考量，紛紛提出措施防備中國公司的電信公司、設備，而相繼出手的大國可能都會對華為、中興等廠商造成不少影響
#
# 0.03136689493237749 根據Reuters報導，海康威視聲稱自己的產品不會危及美國國安，並指出對想要保護自己、家庭或財產的美國小公司、地方政府、學校單位與消費者來說，FCC的決定只會造成負擔，而不會真正保護到國家安全
#
# 0.029584267641412622 英國近日也考量安全風險，仿效美國採取類似措施，禁止各部門在「敏感（Sensitive）」的政府網站上安裝中國公司出產的監控設備
#
# 0.029269812960629714 FCC專員Brendan Carr也在推特上說道：「這次採取行動不僅保護我們的網路，也加強了美國國家安全

# %%
tr.sentence_score_list
# Out:
# [[0.044354676849679586,
#   'FCC主席Jessica Rosenworcel指出，這些廠商的電信與監控產品會對國家與國民安全構成不可接受（unacceptable）的風險，不過FCC實際上並未全面禁止所有產品，如果海能達、海康威視與大華科技三間公司能夠證明，他們旗下用於公共安全、政府設施安全、重要實體監管以及其他國家安全的設備，是銷售給一般消費者，或具有嚴格的安全機制，有可能仍會獲得FCC的許可'],
#  [0.04102851982995048,
#   '11/25，美國聯邦傳播委員會（Federal Communications Commission，FCC）以國家安全風險為由，宣布禁止華為（Huawei）、中興（ZTE）與海能達（Hytera）、海康威視（Hikvision）與大華科技（Dahua）等中國大廠在美販售或進口的通訊與監控設備'],
#  [0.03878360420911449,
#   '同年11月，美國總統拜登簽署《安全設備法》（Secure Equipment Act），要求FCC不可審核或是同意授權任何構成國安風險的設備申請，尤其針對名單上的華為、中興等中國廠商，此法不僅可以解決先前非聯邦資金採購設備的問題，亦被外界視為重挫中國電信與科技大廠的重大立法案'],
#  [0.03870662727173249,
#   '作為進一步打擊中國電信與科技公司的行動，FFC近日表示不再授權黑名單（covered list）內的公司在美販售或進口其設備，華為、中興、海能達、海康威視（Hikvision）與大華科技（Dahua）均列名其中'],
#  [0.037733163777649986,
#   'FCC的新管制政策啟動後，華為、中興、海能達、海康威視與大華科技將無法在美進口與販售其電信設備、影像監視器，預期將讓銷售情況雪上加霜，並且連帶波及到這些廠商背後供應商， 如台灣的晶相光、矽力–KY等 '],
#  [0.03642349893612741,
#   '雖然過去FCC推出黑名單、點明哪些廠商的產品有風險，還禁止企業使用聯邦資金購買這些設備，但是在過去幾年中，FCC依然繼續許可這些設備在市面上販售，只要這類商品獲得授權章，廠商就能持續進貨到美國，賣給其他自掏腰包的買家'],
#  [0.035626198325439944,
#   '加拿大也在今年5月宣布，禁止境內電信業者在5G網路中安裝華為與中興的產品，所有已安裝設備的企業必須停止使用，並立即移除'],
#  [0.034437058767349836,
#   '澳洲則是早在2018年就基於安全考量，禁止華為在澳洲參與5G網路開發，指出這間公司的加入「可能會受到外國政府的指示」，風險實在太大'],
#  [0.03356797408024409, '2021年3月，華為、中興、海能達、海康威視與大華科技五間中國公司就被FCC認定有國安威脅，而列入黑名單'],
#  [0.03320829273621232,
#   '2020年，美國前總統川普曾簽署《安全可信通訊網路法》（Secure and Trusted Communications Networks Act），要求美國電信公司拆除並更換「可疑的外國網路設備」，換言之就是華為與中興提供的產品'],
#  [0.033141992276384265,
#   '同時，FCC專員Carr也呼籲政府處理「華為漏洞」，並指出先前已被替換的網路設備都是由聯邦出資購買，因此仍有企業鑽漏洞，私下購買一樣不安全的產品來使用，而這樣的行為還是會導致風險發生'],
#  [0.032764293873418684,
#   '綜合上述例子，可見由美、英、加、澳、紐五國組成的「五眼聯盟（Five Eyes Alliance，FVEY）」皆出於安全與風險考量，紛紛提出措施防備中國公司的電信公司、設備，而相繼出手的大國可能都會對華為、中興等廠商造成不少影響'],
#  [0.03136689493237749,
#   '根據Reuters報導，海康威視聲稱自己的產品不會危及美國國安，並指出對想要保護自己、家庭或財產的美國小公司、地方政府、學校單位與消費者來說，FCC的決定只會造成負擔，而不會真正保護到國家安全'],
#  [0.029584267641412622,
#   '英國近日也考量安全風險，仿效美國採取類似措施，禁止各部門在「敏感（Sensitive）」的政府網站上安裝中國公司出產的監控設備'],
#  [0.029269812960629714,
#   'FCC專員Brendan Carr也在推特上說道：「這次採取行動不僅保護我們的網路，也加強了美國國家安全'],
#  [0.027101588719234904, '同年，紐西蘭跟隨澳洲的腳步，以國安風險為由，禁止在紐西蘭的5G網路中使用華為設備'],
#  [0.026685529747197533,
#   '去年（2021）美國國會通過了《安全設備法》（The Secure Equipment Act）並交由總統拜登簽署，以防止任何可能構成國安威脅的企業，取得FCC的設備許可'],
#  [0.026586844353627757, '儘管華為曾表示不會將該國境內的客戶數據交給中國，但澳洲政府認為沒有任何安全措施能夠降低此風險'],
#  [0.026514062602800474, '這是我們一致的決定，也是FCC第一次基於國安考量，投票同意禁止特定設備進口'],
#  [0.02574541117541143,
#   '其國內主要的電信營運商都開始與其他廠商合作，加拿大公共安全部長Marco Mendicino也表示政府已展開廣大的調查，希望可以保護資料與人民的安全'],
#  [0.023805389653700416,
#   '」此外，雖然新政策不具追溯力，上述中國企業仍可繼續銷售已獲准的產品，但新政策更允許委員會撤銷對其他設備現有的授權'],
#  [0.023617722793661144, '國安風險為優先考量，不准黑名單公司商品進口'],
#  [0.02244193472445239,
#   '本來6月還在考慮禁止授權的FCC終於在11月底正式發出公告，委員會中屬於民主黨的Jessica Rosenworcel與Geoffrey Starks、共和黨的Brendan Carr與Nathan Simington都非常支持新政策的啟動'],
#  [0.022212694381627936, '另外，海康威視也表示未來會持續遵守美國政府規範，為消費者提供服務'],
#  [0.02198672471589176, '本來只局限於軍事、政府的制裁範圍，如今擴大到民間生活，美國對於中國企業的制裁恐怕只會越來越大'],
#  [0.0216518523731496, '不只有美國！英、加、紐澳也出手制裁'],
#  [0.02068482967728226, '以晶相光（3530）為例，海康威視為其旗下產品CMOS影像感測器的最大客戶，用於製造安全監控、消費性產品'],
#  [0.020267391032803728, '近年來，中美關係的緊張讓美國政府越來越注重國安問題'],
#  [0.019120228172003075, '在夾縫中求生存的元件供應商或許會連帶受損，但若能抓準商機填補市場空缺，在未來可能也會創造出一片佳績'],
#  [0.018613722556227705,
#   '反之，美國政府此次封殺中國科技業之舉，可能間接創造需求缺口，讓 台灣安控廠晶睿、奇偶、陞泰等因此受惠，進而接到北美市場的轉單與訂單 '],
#  [0.018585018038631537, '目前任何相關設備皆不可連接到部門內的核心網域，如有疑慮，應評估並拆除，或更換至其他地方'],
#  [0.016712741842696093, '從川普到拜登，FCC一步步打擊中國大廠'],
#  [0.016418844045271393,
#   '以積極布局國際市場的晶睿為例，中美貿易戰未歇與供應鏈缺料緩解的情況下，其在今年第三季稅後收益達2.22億，季漲幅高達63%，創下亮眼好成績'],
#  [0.01640197404343327, '管制啟動後，哪些廠商會受影響？哪些廠商受惠？'],
#  [0.015917445320550998, '此外，政府也希望能逐漸擴大風險管理範圍'],
#  [0.014289930417512071, '所以要真正杜絕這個問題，必須要從禁止授權開始'],
#  [0.012325015390083393,
#   '因應該法案，FCC也提出補償計畫，補助符合條件的供應商替換成其他廠商的設備，該計畫所需費用估值超過18億美元'],
#  [0.01231622775502557, '而目前FCC尚未行使撤銷權，Carr則相當期待與同事一起達成此目標']]
